# %% [markdown]
# ## Машинное обучение 1, ПМИ ФКН ВШЭ
#
# ## Практическое домашнее задание 1
#
# ### Общая информация
#
# Дата выдачи: 11.09.2021
#
# Мягкий дедлайн: 23:59MSK 25.09.2021
#
# Жесткий дедлайн: 23:59MSK 28.09.2021

# %%
# %config Completer.use_jedi = False

# %% [markdown]
# ### О задании
#
# Задание состоит из двух разделов, посвященных работе с табличными данными с помощью библиотеки pandas и визуализации с помощью matplotlib. В первом разделе вам предстоит выполнить базовые задания с помощью вышеуказанных библиотек, а во втором распределить студентов по курсам. Баллы даются за выполнение отдельных пунктов. Задачи в рамках одного раздела рекомендуется решать в том порядке, в котором они даны в задании.
#
# Задание направлено на освоение jupyter notebook (будет использоваться в дальнейших заданиях), библиотек pandas и matplotlib.
#
# ### Оценивание и штрафы
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — 10 баллов.
#
# Сдавать задание после жёсткого дедлайна нельзя. При выставлении неполного балла за задание в связи с наличием ошибок на усмотрение проверяющего предусмотрена возможность исправить работу на указанных в ответном письме условиях.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов (подробнее о плагиате см. на странице курса). Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# ### Формат сдачи
# Задания сдаются через систему Anytask. Инвайт можно получить у семинариста или ассистента. Присылать необходимо ноутбук с выполненным заданием. Сам ноутбук называйте в формате homework-practice-01-pandas-Username.ipynb, где Username — ваша фамилия.
#
# Для удобства проверки самостоятельно посчитайте свою максимальную оценку (исходя из набора решенных задач) и укажите ниже.
#
# Оценка: xx.

# %% [markdown]
# ## 0. Введение

# %% [markdown]
# Сейчас мы находимся в jupyter-ноутбуке (или ipython-ноутбуке). Это удобная среда для написания кода, проведения экспериментов, изучения данных, построения визуализаций и других нужд, не связанных с написанием production-кода.
#
# Ноутбук состоит из ячеек, каждая из которых может быть либо ячейкой с кодом, либо ячейкой с текстом размеченным и неразмеченным. Текст поддерживает markdown-разметку и формулы в Latex.
#
# Для работы с содержимым ячейки используется *режим редактирования* (*Edit mode*, включается нажатием клавиши **Enter** после выбора ячейки), а для навигации между ячейками искользуется *командный режим* (*Command mode*, включается нажатием клавиши **Esc**). Тип ячейки можно задать в командном режиме либо с помощью горячих клавиш (**y** to code, **m** to markdown, **r** to edit raw text), либо в меню *Cell -> Cell type*.
#
# После заполнения ячейки нужно нажать *Shift + Enter*, эта команда обработает содержимое ячейки: проинтерпретирует код или сверстает размеченный текст.

# %%
# ячейка с кодом, при выполнении которой появится output
2 + 2
# Out:
# 4

# %% [markdown]
# Ячейка с неразмеченыным текстом.

# %% [markdown]
# Попробуйте создать свои ячейки, написать какой-нибудь код и текст какой-нибудь формулой.

# %%
# your code

# %% [markdown]
# [Здесь](https://athena.brynmawr.edu/jupyter/hub/dblank/public/Jupyter%20Notebook%20Users%20Manual.ipynb) находится <s>не</s>большая заметка о используемом языке разметки Markdown. Он позволяет:
#
# 0. Составлять упорядоченные списки
# 1. Выделять *текст* <s>при</s> **необходимости**
# 2. Добавлять [ссылки](http://imgs.xkcd.com/comics/the_universal_label.png)
#
#
# * Составлять неупорядоченные списки
#
# Делать вставки с помощью LaTex:
#
# $
# \left\{
# \begin{array}{ll}
# x = 16 \sin^3 (t) \\
# y = 13 \cos (t) - 5 \cos (2t) - 2 \cos (3t) - \cos (4t) \\
# t \in [0, 2 \pi]
# \end{array}
# \right.$

# %% [markdown]
# А ещё можно вставлять картинки, или гифки, или что захотите:
#
# <img src="https://media1.tenor.com/images/9b8fbe9214504bcf6c60fe4e4f7e114e/tenor.gif?itemid=5416416" style="width: 400px">

# %% [markdown]
# ### Google Colab

# %% [markdown]
# Что за колаб?
#
# **Google Colab (Colaboratory)** это **Jupyter Notebook + Cloud + Google Drive.**
#
# Компания Google предоставляет возможность бесплатно запускать ноутбуки (предварительно загрузив их на свой гугл-диск) прямо в облаке. При этом вам не требуется установка никаких пакетов на свою машину, а работать можно прямиком из браузера. Вот ссылка:

# %% [markdown]
# https://colab.research.google.com

# %% [markdown]
# При использовании вы увидете много сходств с jupyter ноутбуком. Одним из преимуществ является доступность GPU, соответствующую опцию можно активировать в настройках сервиса. При желании вы сможете найти в интернете много туториалов по использованию или разобраться самостоятельно =)

# %% [markdown]
# ## 1. Табличные данные и Pandas

# %% [markdown]
# Pandas — удобная библиотека для работы с табличными данными в Python, если данных не слишком много и они помещаются в оперативную память вашего компьютера. Несмотря на неэффективность реализации и некоторые проблемы, библиотека стала стандартом в анализе данных.
#
# Основной объект в pandas — это DataFrame, представляющий собой таблицу с именованными колонками различных типов, индексом (может быть многоуровневым). DataFrame можно создавать, считывая таблицу из файла или задавая вручную из других объектов.
#
# В этой части потребуется выполнить несколько небольших заданий. Можно пойти двумя путями: сначала изучить материалы, а потом приступить к заданиям, или же разбираться "по ходу". Выбирайте сами.
#
# Материалы:
# 1. [Pandas за 10 минут из официального руководства](http://pandas.pydata.org/pandas-docs/stable/10min.html)
# 2. [Документация](http://pandas.pydata.org/pandas-docs/stable/index.html) (стоит обращаться, если не понятно, как вызывать конкретный метод)
# 3. [Примеры использования функционала](http://nbviewer.jupyter.org/github/justmarkham/pandas-videos/blob/master/pandas.ipynb)
#
# Многие из заданий можно выполнить несколькими способами. Не существуют единственно верного, но попробуйте максимально задействовать арсенал pandas и ориентируйтесь на простоту и понятность вашего кода. Мы не будем подсказывать, что нужно использовать для решения конкретной задачи, попробуйте находить необходимый функционал сами (название метода чаще всего очевидно). В помощь вам документация, поиск и stackoverflow.

# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Скачаем данные:

# %%
# !wget  -O 'end_seminar.xlsx' -q 'https://www.dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=0'

# %% [markdown]
# Для пользователей Windows: скачайте файл самостоятельно и поместите его в папку с тетрадкой. Или попробуйте один из следующих вариантов:

# %%
# !powershell iwr -outf somefile https://somesite/somefile

# %%
# !pip install wget
# import wget 
# wget.download('https://dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=1', 'end_seminar.xlsx')

# %% [markdown]
# ##### В первой части задания (до раздела "Распределение студентов по курсам") использование циклов запрещается и повлечет за собой снижение оценки. Использование <code>vectorize</code> и  <code>apply</code>, <code>apply_along_axis</code> крайне нежелательно.

# %% [markdown]
# Для каждой задачи из этого раздела вы должны написать код для получения ответа, а также дать текстовый ответ, если он предполагается.
#
# На некоторые вопросы вы можете получить ответ путём пристального взгляда на таблицу, но это не будет засчитываться. Вы в любом случае должны получить ответ с помощью кода.

# %% [markdown]
# #### 1. [0 баллов] Откройте файл с таблицей (не забудьте про её формат). Выведите последние 10 строк.
#
# Посмотрите на данные и скажите, что они из себя представляют, сколько в таблице строк, какие столбцы? (на это не надо отвечать, просто подумайте об этом)

# %%
data = pd.read_excel("end_seminar.xlsx")

# %%
data.tail(10)
# Out:
#                   timestamp                                id  rating  \
# 351 2020-05-18 23:58:33.903  8fe79f84f36e3a5d2d6745621321302c    1016
# 352 2020-05-18 23:59:20.831  f93afd8e92c336b471aa3bbbc579aefe    1298
# 353 2020-05-18 23:59:28.998  9963fc00d9405a35b894cc04a7e19855    1135
# 354 2020-05-19 08:55:39.509  98c5a2548d93f26bd4195466e93178b3    1035
# 355 2020-05-19 18:58:06.283  ba298cbd9be59b84bab33325e956f27e    1155
# 356 2020-05-19 19:04:17.873  c5870b37ee3f672e4259dfb2fc02ed8f    1029
# 357 2020-05-19 20:19:25.815  f44aea1095f9f5b8e2f5f0ed2b17891b    1060
# 358 2020-05-20 11:54:38.318  d7118b44c7e8fdbbaaca226d2da6fef1    1111
# 359 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 360 2020-05-23 21:16:40.916  f2d210ace25a841e1e58036b257d5d47    1195
#
#      18_group  is_mi                                           fall_1  \
# 351       NaN    NaN                 Безопасность компьютерных систем
# 352       NaN    NaN                Высокопроизводительные вычисления
# 353       NaN    NaN                 Безопасность компьютерных систем
# 354       NaN    NaN            Байесовские методы машинного обучения
# 355       NaN    NaN  Сбор и обработка данных с помощью краудсорсинга
# 356       NaN    NaN                      Statistical Learning Theory
# 357       NaN    NaN                Анализ неструктурированных данных
# 358       NaN    NaN  Сбор и обработка данных с помощью краудсорсинга
# 359       NaN    NaN                 Безопасность компьютерных систем
# 360       NaN    NaN                Анализ неструктурированных данных
#
#                                                 fall_2  \
# 351                  Высокопроизводительные вычисления
# 352    Сбор и обработка данных с помощью краудсорсинга
# 353                  Высокопроизводительные вычисления
# 354               Глубинное обучение в обработке звука
# 355              Байесовские методы машинного обучения
# 356                  Анализ неструктурированных данных
# 357                  Высокопроизводительные вычисления
# 358                        Statistical Learning Theory
# 359  Принятие решений в условиях риска и неопределё...
# 360                      Моделирование временных рядов
#
#                                               fall_3  \
# 351  Сбор и обработка данных с помощью краудсорсинга
# 352                      Statistical Learning Theory
# 353                 Безопасность компьютерных систем
# 354                      Statistical Learning Theory
# 355                Анализ неструктурированных данных
# 356  Сбор и обработка данных с помощью краудсорсинга
# 357                    Моделирование временных рядов
# 358                Анализ неструктурированных данных
# 359                Анализ неструктурированных данных
# 360                Высокопроизводительные вычисления
#
#                                               spring_1  \
# 351                             Конфликты и кооперация
# 352               Методы сжатия и передачи медиаданных
# 353  Проектирование и разработка высоконагруженных ...
# 354                           Обучение с подкреплением
# 355                             Конфликты и кооперация
# 356                           Обучение с подкреплением
# 357                             Конфликты и кооперация
# 358  Проектирование и разработка высоконагруженных ...
# 359  Проектирование и разработка высоконагруженных ...
# 360                           Обучение с подкреплением
#
#                                               spring_2  \
# 351  Проектирование и разработка высоконагруженных ...
# 352  Проектирование и разработка высоконагруженных ...
# 353               Методы сжатия и передачи медиаданных
# 354            Генеративные модели в машинном обучении
# 355                           Обучение с подкреплением
# 356                             Конфликты и кооперация
# 357                           Обучение с подкреплением
# 358               Методы сжатия и передачи медиаданных
# 359               Методы сжатия и передачи медиаданных
# 360                                Компьютерное зрение
#
#                                  spring_3 is_first_time  percentile  17_group  \
# 351                 Символьные вычисления            Да    0.942029     174.0
# 352                Конфликты и кооперация            Да    0.057971     175.0
# 353                 Символьные вычисления            Да    0.572464     175.0
# 354  Методы сжатия и передачи медиаданных           Нет    0.905797     171.0
# 355                   Компьютерное зрение            Да    0.507246     171.0
# 356                   Компьютерное зрение            Да    0.920290     174.0
# 357                      Численные методы            Да    0.840580     174.0
# 358                      Численные методы            Да    0.652174     173.0
# 359                   Компьютерное зрение            Да    0.985507     172.0
# 360  Методы сжатия и передачи медиаданных           NaN    0.369565     176.0
#
#                             blended  is_ml_student
# 351                          DevOps            NaN
# 352                          DevOps            NaN
# 353                          DevOps            NaN
# 354                          DevOps            NaN
# 355  Соревновательный анализ данных            NaN
# 356                          DevOps            NaN
# 357                          DevOps            NaN
# 358  Соревновательный анализ данных            NaN
# 359                          DevOps            NaN
# 360  Соревновательный анализ данных            NaN

# %%
data.shape
# Out:
# (361, 16)

# %% [markdown]
# 361 строка в таблице

# %%
data.describe()
# Out:
#             rating    18_group  is_mi  percentile    17_group  is_ml_student
# count   361.000000  223.000000   18.0  361.000000  138.000000           57.0
# mean    833.346260  184.520179    1.0    0.497230  173.355072            1.0
# std     266.665103    2.271701    0.0    0.289071    1.795374            0.0
# min     495.000000  181.000000    1.0    0.000000  171.000000            1.0
# 25%     613.000000  183.000000    1.0    0.246637  172.000000            1.0
# 50%     697.000000  185.000000    1.0    0.497758  173.000000            1.0
# 75%    1111.000000  187.000000    1.0    0.746377  175.000000            1.0
# max    1457.000000  188.000000    1.0    0.995516  177.000000            1.0

# %%
data.dtypes
# Out:
# timestamp        datetime64[ns]
# id                       object
# rating                    int64
# 18_group                float64
# is_mi                   float64
# fall_1                   object
# fall_2                   object
# fall_3                   object
# spring_1                 object
# spring_2                 object
# spring_3                 object
# is_first_time            object
# percentile              float64
# 17_group                float64
# blended                  object
# is_ml_student           float64
# dtype: object

# %% [markdown]
# #### 2. [0.5 балла] Ответьте на вопросы:
# 1. Сколько было заявок из групп 18-го года набора, а сколько из групп 17-го года?
# 2. Есть ли студенты с равными перцентилями?

# %%
(~data.isna()["18_group"]).sum()
# Out:
# 223

# %%
data.groupby(by="18_group").sum()
# Out:
#           rating  is_mi  percentile  17_group  is_ml_student
# 18_group
# 181.0      17771    0.0   10.627803       0.0            7.0
# 182.0      17942    1.0    7.000000       0.0           17.0
# 183.0      20024    0.0   16.834081       0.0            6.0
# 184.0      14478    4.0   11.856502       0.0            4.0
# 185.0      19242    4.0   16.968610       0.0            5.0
# 186.0      17054    3.0   13.318386       0.0           10.0
# 187.0      19067    1.0   21.000000       0.0            7.0
# 188.0      15562    5.0   13.394619       0.0            1.0

# %% [markdown]
# В таблице 223 заявок из групп 18-го года набора

# %%
(~data.isna()["17_group"]).sum()
# Out:
# 138

# %% [markdown]
# И 138 заявок из групп 17-го года наборы

# %%
138 + 223
# Out:
# 361

# %% [markdown]
# В таблице ровно 361 строка, то есть всё сходится и никто не потерян)

# %%
data["percentile"].unique().size
# Out:
# 346

# %% [markdown]
# То есть в таблице всего 346 уникальных значений перцентиля, получается,
# что студенты с равными перцентилями есть

# %% [markdown]
# #### 3. [0.5 балла] Есть ли в данных пропуски? В каких колонках? Сколько их в каждой из этих колонок?

# %%
data.isna().sum()
# Out:
# timestamp          0
# id                 0
# rating             0
# 18_group         138
# is_mi            343
# fall_1             0
# fall_2             0
# fall_3             0
# spring_1           0
# spring_2           0
# spring_3           0
# is_first_time      2
# percentile         0
# 17_group         223
# blended          223
# is_ml_student    304
# dtype: int64

# %% [markdown]
# Пропуски есть в колонках: 18_group (138), is_mi (343), is_first_time (2), 17_group (223), blended (223), is_ml_student (304)

# %% [markdown]
# Заполните пропуски пустой строкой для строковых колонок и нулём для числовых.

# %%
data.fillna(value=dict.fromkeys(['is_first_time', 'blended'], ''), inplace=True)

# %%
data.fillna(value=dict.fromkeys(['18_group', 'is_mi', '17_group', 'is_ml_student'], 0),
            inplace=True)

# %%
data.head()
# Out:
#                 timestamp                                id  rating  18_group  \
# 0 2020-05-15 01:12:50.543  93ff79a51cd602f1dd3028ba2c129503     698     181.0
# 1 2020-05-15 02:46:48.066  26b01b1c4cd5656bab18d24c548834fb     647     181.0
# 2 2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd     624     185.0
# 3 2020-05-15 04:43:08.994  1528f0eaa027580820ccf0d92a53ad68     579     182.0
# 4 2020-05-15 07:47:17.197  496ea4f0d4abe264b1bb1b80eb3830c5     572     183.0
#
#    is_mi                             fall_1  \
# 0    0.0                           Язык SQL
# 1    0.0  Высокопроизводительные вычисления
# 2    0.0   Безопасность компьютерных систем
# 3    0.0        Statistical Learning Theory
# 4    0.0  Высокопроизводительные вычисления
#
#                               fall_2                         fall_3  \
# 0  Высокопроизводительные вычисления           Матричные вычисления
# 1   Безопасность компьютерных систем                       Язык SQL
# 2               Матричные вычисления  Моделирование временных рядов
# 3  Высокопроизводительные вычисления           Матричные вычисления
# 4   Безопасность компьютерных систем              Теория баз данных
#
#                  spring_1                spring_2             spring_3  \
# 0  Дискретная оптимизация        Численные методы  Машинное обучение 2
# 1  Дискретная оптимизация        Численные методы  Машинное обучение 2
# 2  Дискретная оптимизация     Машинное обучение 2     Численные методы
# 3  Дискретная оптимизация        Численные методы  Машинное обучение 2
# 4       Компьютерные сети  Дискретная оптимизация     Численные методы
#
#   is_first_time  percentile  17_group blended  is_ml_student
# 0            Да    0.183857       0.0                    0.0
# 1           Нет    0.426009       0.0                    0.0
# 2            Да    0.538117       0.0                    0.0
# 3            Да    0.744395       0.0                    0.0
# 4            Да    0.780269       0.0                    0.0

# %% [markdown]
# #### 4. [0.5 балла] Посмотрите повнимательнее на колонку 'is_first_time'.
#
# Есть ли в ней ответы "Нет"? Сколько их?
#
# Если вы найдете повторные обращения студентов, оставьте только самую позднюю версию. <i>Обращения со значением "Нет" в <code>is_first_time</code> могут быть как повторными, так и первичными, поскольку поле заполняли сами студенты.</i>

# %%
data[data['is_first_time'] == 'Нет'].shape
# Out:
# (51, 16)

# %% [markdown]
# В таблице 51 записей с ответом "Нет"

# %%
data = data.sort_values(by=['id', 'is_first_time', 'timestamp'])

# %%
data = data.drop_duplicates(subset=['id'], keep='last')

# %%
data.shape
# Out:
# (347, 16)

# %% [markdown]
# Так как я рассматривала только дубликаты, то записи, которые были единичными, где человек по ошибке указал "Нет", не были удалены

# %% [markdown]
# #### 5. [0.5 балла] Какие  blended-курсы для четверокурсников существуют? На какой blended-курс записалось наибольшее количество студентов? На каком из курсов собрались студенты с самым высоким средним рейтингом?

# %%
data[data['18_group'] != 0].blended.unique()
# Out:
# array([''], dtype=object)

# %%
data[data['17_group'] != 0].blended.unique()
# Out:
# array(['Соревновательный анализ данных', 'DevOps',
#        'Введение в дифференциальную геометрию'], dtype=object)

# %% [markdown]
# Всего три blended-курса для четверокурсников (групп 17 года поступления), они представлнеы выше

# %%
data[data['17_group'] != 0].groupby('blended').size()
# Out:
# blended
# DevOps                                   87
# Введение в дифференциальную геометрию    15
# Соревновательный анализ данных           32
# dtype: int64

# %% [markdown]
# Больше всего студенов записаловь на курас "DevOps", меньше всего на "Введение в дифференциальную геометрию"

# %%
data[data['17_group'] != 0].groupby('blended').mean()['rating']
# Out:
# blended
# DevOps                                   1154.172414
# Введение в дифференциальную геометрию    1210.733333
# Соревновательный анализ данных           1144.218750
# Name: rating, dtype: float64

# %% [markdown]
# Самый высокий стредний рейтинг на курсе "Введение в дифференциальную геометрию", самый низкий на курсе "Соревновательный анализ данных"

# %% [markdown]
# #### 6. [1 балл] Выясните, есть ли в данных студенты с абсолютно одинаковыми предпочтениями по всем курсам (не забудьте учесть blended-курсы для четверокурсников). Сколько таких наборов, которые взяли несколько студентов? Выведите их все вместе с количеством выбравших их студентов.
#
# <i>Предпочтения двух студентов считаются абсолютно одинаковыми, если выбранные ими дисциплины имеют одинаковый приоритет.</i>

# %%
data.head(3)
# Out:
#                   timestamp                                id  rating  \
# 161 2020-05-18 22:08:11.668  00b40fe7dbfd23e5daba765244509415     542
# 76  2020-05-18 16:47:43.131  014b72217e20370dab7acc48b20c47be     543
# 335 2020-05-18 23:01:39.666  01b072a0cdb45814fc4ab8ca3e621f0e    1058
#
#      18_group  is_mi                                           fall_1  \
# 161     187.0    0.0                 Безопасность компьютерных систем
# 76      186.0    0.0  Сбор и обработка данных с помощью краудсорсинга
# 335       0.0    0.0                Анализ неструктурированных данных
#
#                                               fall_2  \
# 161                                         Язык SQL
# 76                       Statistical Learning Theory
# 335  Сбор и обработка данных с помощью краудсорсинга
#
#                             fall_3  \
# 161           Матричные вычисления
# 76            Матричные вычисления
# 335  Моделирование временных рядов
#
#                                         spring_1             spring_2  \
# 161  Промышленное программирование на языке Java    Компьютерные сети
# 76                            Системы баз данных  Машинное обучение 2
# 335                     Обучение с подкреплением  Компьютерное зрение
#
#                     spring_3 is_first_time  percentile  17_group  \
# 161  Анализ данных в бизнесе            Да    0.896861       0.0
# 76    Дискретная оптимизация            Да    0.892377       0.0
# 335    Символьные вычисления            Да    0.847826     173.0
#
#                             blended  is_ml_student
# 161                                            0.0
# 76                                             0.0
# 335  Соревновательный анализ данных            0.0

# %%
data.duplicated(
    subset=['fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended'],
    keep='first').sum()
# Out:
# 17

# %%
mask = data.duplicated(
    subset=['fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended'],
    keep=False)
mask.sum()
# Out:
# 32

# %% [markdown]
# В таблице имеется 17 совпадений

# %%
grouped = data[mask].groupby(
    by=['fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended'])

# %%
pd.DataFrame(grouped['id'].count())
# Out:
#                                                                                                                                                                                                                                                                                                     id
# fall_1                                          fall_2                                          fall_3                                          spring_1                                           spring_2                                    spring_3                                    blended
# Statistical Learning Theory                     Анализ неструктурированных данных               Сбор и обработка данных с помощью краудсорсинга Обучение с подкреплением                           Конфликты и кооперация                      Компьютерное зрение                         DevOps    2
# Байесовские методы машинного обучения           Анализ неструктурированных данных               Глубинное обучение в обработке звука            Обучение с подкреплением                           Генеративные модели в машинном обучении     Компьютерное зрение                         DevOps    2
#                                                                                                 Сбор и обработка данных с помощью краудсорсинга Обучение с подкреплением                           Компьютерное зрение                         Генеративные модели в машинном обучении     DevOps    2
# Безопасность компьютерных систем                Statistical Learning Theory                     Матричные вычисления                            Дискретная оптимизация                             Промышленное программирование на языке Java Дополнительные главы прикладной статистики            3
#                                                 Высокопроизводительные вычисления               Анализ неструктурированных данных               Проектирование и разработка высоконагруженных с... Методы сжатия и передачи медиаданных        Конфликты и кооперация                      DevOps    2
#                                                                                                 Язык SQL                                        Компьютерные сети                                  Промышленное программирование на языке Java Дискретная оптимизация                                3
#                                                                                                                                                 Промышленное программирование на языке Java        Компьютерные сети                           Системы баз данных                                    2
#                                                 Матричные вычисления                            Моделирование временных рядов                   Промышленное программирование на языке Java        Компьютерные сети                           Дискретная оптимизация                                2
#                                                 Сбор и обработка данных с помощью краудсорсинга Матричные вычисления                            Компьютерные сети                                  Промышленное программирование на языке Java Анализ данных в бизнесе                               2
#                                                 Теория баз данных                               Язык SQL                                        Машинное обучение 2                                Компьютерные сети                           Промышленное программирование на языке Java           2
# Высокопроизводительные вычисления               Безопасность компьютерных систем                Сбор и обработка данных с помощью краудсорсинга Проектирование и разработка высоконагруженных с... Методы сжатия и передачи медиаданных        Компьютерное зрение                         DevOps    2
#                                                 Сбор и обработка данных с помощью краудсорсинга Моделирование временных рядов                   Проектирование и разработка высоконагруженных с... Методы сжатия и передачи медиаданных        Методы сжатия и передачи медиаданных        DevOps    2
# Моделирование временных рядов                   Сбор и обработка данных с помощью краудсорсинга Безопасность компьютерных систем                Компьютерные сети                                  Дополнительные главы прикладной статистики  Системы баз данных                                    2
# Сбор и обработка данных с помощью краудсорсинга Язык SQL                                        Теория баз данных                               Промышленное программирование на языке Java        Машинное обучение 2                         Компьютерные сети                                     2
# Язык SQL                                        Высокопроизводительные вычисления               Теория баз данных                               Компьютерные сети                                  Промышленное программирование на языке Java Дискретная оптимизация                                2

# %% [markdown]
# Вывод получился в формате групп, но тем не менее он отражает поставленную задачу и показывает, сколько студентов выбрали одинаковый набор предметов

# %% [markdown]
# #### 7. [0.5 балла] Найдите курсы по выбору, на которые записывались как студенты 18-го года набора, так и студенты 17-го года.

# %%
set_subj = set()
for col in ['fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended']:
    set_subj.update(set(data[col].unique()))
len(set_subj)
# Out:
# 31

# %% [markdown]
# Всего существует 31 различный курс по выбору (включая blended-курсы)

# %%
len(data['fall_1'].unique()) + len(data['spring_1'].unique()) + len(data['blended'].unique())
# Out:
# 31

# %% [markdown]
# Размеры совпали, таким образом, колонки 'fall_1', 'spring_1' и 'blended' полностью содержат весь набор курсов, поэтому можно рассматривать только их

# %%
data[(data['blended'] != '') & (data['18_group'] != 0)].shape
# Out:
# (0, 16)

# %% [markdown]
# Это было очевидно, но я перепроверила, что множество blended-курсов не пересекается с множеством всех стальных курсов по выбору, поэтому эту колонку можно не рассматривать при нахождении курсов, которые выбирают студенты 17-го и 18-го годов

# %%
set_17 = set(data.loc[data['17_group'] != 0, 'fall_1'].unique())
set_17.update(set(data.loc[data['17_group'] != 0, 'spring_1'].unique()))
set_18 = set(data.loc[data['18_group'] != 0, 'fall_1'].unique())
set_18.update(set(data.loc[data['18_group'] != 0, 'spring_1'].unique()))

intersection = set_17.intersection(set_18)
intersection
# Out:
# {'Statistical Learning Theory',
#  'Безопасность компьютерных систем',
#  'Высокопроизводительные вычисления',
#  'Моделирование временных рядов',
#  'Принятие решений в условиях риска и неопределённости',
#  'Сбор и обработка данных с помощью краудсорсинга',
#  'Численные методы'}

# %% [markdown]
# Это курсы, на которые записывались студенты и 17-го и 18-го года

# %% [markdown]
# Методом исключения найдите курсы, которые предлагались только студентам 18-го года и только студентам 17-го года.

# %%
set_17.difference(intersection)
# Out:
# {'Анализ неструктурированных данных',
#  'Байесовские методы машинного обучения',
#  'Генеративные модели в машинном обучении',
#  'Глубинное обучение в обработке звука',
#  'Компьютерное зрение',
#  'Конфликты и кооперация',
#  'Методы сжатия и передачи медиаданных',
#  'Обучение с подкреплением',
#  'Проектирование и разработка высоконагруженных сервисов',
#  'Символьные вычисления'}

# %% [markdown]
# Это курсы, на которые записывались только студенты 18-го года

# %%
set_18.difference(intersection)
# Out:
# {'Анализ данных в бизнесе',
#  'Дискретная оптимизация',
#  'Дополнительные главы прикладной статистики',
#  'Компьютерные сети',
#  'Матричные вычисления',
#  'Машинное обучение 2',
#  'Промышленное программирование на языке Java',
#  'Системы баз данных',
#  'Теория баз данных',
#  'Язык SQL'}

# %% [markdown]
# Это курсы, на которые записывались только студенты 17-го года

# %% [markdown]
# ### Визуализации и matplotlib

# %% [markdown]
# При работе с данными часто неудобно делать какие-то выводы, если смотреть на таблицу и числа в частности, поэтому важно уметь визуализировать данные. Здесь будут описаны ключевые правила оформления графиков для **всех** домашних заданий.
#
# У matplotlib, конечно же, есть [документация](https://matplotlib.org/users/index.html) с большим количеством [примеров](https://matplotlib.org/examples/), но для начала достаточно знать про несколько основных типов графиков:
# - plot — обычный поточечный график, которым можно изображать кривые или отдельные точки;
# - hist — гистограмма, показывающая распределение некоторой величины;
# - scatter — график, показывающий взаимосвязь двух величин;
# - bar — столбцовый график, показывающий взаимосвязь количественной величины от категориальной.
#
# В этом задании вы попробуете построить один из них. Не забывайте про базовые принципы построения приличных графиков:
# - оси должны быть подписаны, причём не слишком мелко;
# - у графика должно быть название;
# - если изображено несколько графиков, то необходима поясняющая легенда;
# - все линии на графиках должны быть чётко видны (нет похожих цветов или цветов, сливающихся с фоном);
# - если отображена величина, имеющая очевидный диапазон значений (например, проценты могут быть от 0 до 100), то желательно масштабировать ось на весь диапазон значений (исключением является случай, когда вам необходимо показать малое отличие, которое незаметно в таких масштабах);
# - сетка на графике помогает оценить значения в точках на глаз, это обычно полезно, поэтому лучше ее отрисовывать;
# - если распределение на гистограмме имеет тяжёлые хвосты, лучше использовать логарифмическую шкалу.
#
# Полезные строчки:
# - для красивой картинки <code>%config InlineBackend.figure_format = 'retina'</code>
# - задаем размер (почти) всех графиков (можно выбрать другие значения) <code>plt.rcParams['figure.figsize'] = 8, 5</code>
# - размер шрифта подписей графиков <code>plt.rcParams['font.size'] = 12</code>
# - формат в котором сохраняется изображение <code>mpl.rcParams['savefig.format'] = 'pdf'</code>
# - sns – seaborn, добавляет решетку <code>sns.set_style('darkgrid')</code>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data.head(3)
# Out:
#                   timestamp                                id  rating  \
# 161 2020-05-18 22:08:11.668  00b40fe7dbfd23e5daba765244509415     542
# 76  2020-05-18 16:47:43.131  014b72217e20370dab7acc48b20c47be     543
# 335 2020-05-18 23:01:39.666  01b072a0cdb45814fc4ab8ca3e621f0e    1058
#
#      18_group  is_mi                                           fall_1  \
# 161     187.0    0.0                 Безопасность компьютерных систем
# 76      186.0    0.0  Сбор и обработка данных с помощью краудсорсинга
# 335       0.0    0.0                Анализ неструктурированных данных
#
#                                               fall_2  \
# 161                                         Язык SQL
# 76                       Statistical Learning Theory
# 335  Сбор и обработка данных с помощью краудсорсинга
#
#                             fall_3  \
# 161           Матричные вычисления
# 76            Матричные вычисления
# 335  Моделирование временных рядов
#
#                                         spring_1             spring_2  \
# 161  Промышленное программирование на языке Java    Компьютерные сети
# 76                            Системы баз данных  Машинное обучение 2
# 335                     Обучение с подкреплением  Компьютерное зрение
#
#                     spring_3 is_first_time  percentile  17_group  \
# 161  Анализ данных в бизнесе            Да    0.896861       0.0
# 76    Дискретная оптимизация            Да    0.892377       0.0
# 335    Символьные вычисления            Да    0.847826     173.0
#
#                             blended  is_ml_student
# 161                                            0.0
# 76                                             0.0
# 335  Соревновательный анализ данных            0.0

# %% [markdown]
# #### 8. [0.5 балла] Постройте график средних рейтингов по дням получения ответов (bar plot).

# %%
from matplotlib.backends.backend_pdf import PdfPages

# %%
pp = PdfPages('bar_plot.pdf')
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['font.family'] = 'Calibri'

fig = plt.figure(figsize=(10, 6))

ax = fig.add_subplot()

sns.barplot(
    x=sort(data.timestamp.dt.date.unique()),
    y=data.groupby(by=data.timestamp.dt.date)['rating'].mean(),
    color='olive')

ax.tick_params(axis='x', labelrotation=45)

ax.grid(axis='y', linestyle=':')

fig.set_facecolor('floralwhite')
ax.set_facecolor('seashell')
ax.set_xlabel('Date', fontsize=14)
ax.set_ylabel('Rating', fontsize=14)
ax.set_title('Зависимость среднего рейтинга от даты', fontsize=20)

pp.savefig()
pp.close()

# %% [markdown]
# Сохраните график в формате pdf (так он останется векторизованным).

# %% [markdown]
# Еще одна билиотека для визуализации: [seaborn](https://jakevdp.github.io/PythonDataScienceHandbook/04.14-visualization-with-seaborn.html). Это настройка над matplotlib, иногда удобнее и красивее делать визуализации через неё.

# %% [markdown]
# Добавила необходимые строки для сохраниения в pdf в ячейку выше

# %% [markdown]
# ### 2. Распределение студентов по курсам.

# %% [markdown]
# Теперь вам нужно распределить студентов по осенним курсам по выбору, учитывая их предпочтения.

# %% [markdown]
# Алгоритм распределения студентов по курсам:
# 1. По умолчанию на каждой дисциплине по выбору у 3 и 4 курсов может учиться 1 группа (до 30 студентов). Исключения описаны ниже. На blended-дисциплинах для четверокурсников количество мест не ограничено.
# 2. Проводится первая волна отбора. Для каждой дисциплины формируется список тех, кто указал её первым приоритетом (если студент должен выбрать два курса по выбору, то для него дисциплины, которые он указал первым и вторым приоритетом, рассматриваются как дисциплины первого приоритета). Если желающих больше, чем мест, то выбирается топ по перцентилю рейтинга.
# 3. На дисциплинах, где остались места после первой волны, формируются списки тех, кто выбрал их вторым приоритетом, и места заполняются лучшими по перцентили рейтинга студентами. После этого проводится такая же процедура для дисциплин третьего приоритета.
# 4. Если студент не попал на необходимое количество курсов по итогам трёх волн, с ним связывается учебный офис и решает вопрос в индивидуальном порядке.

# %% [markdown]
# Обращаем ваше внимание на следующие детали:
#
# - По умолчанию студент выбирает один осенний и один весенний курс по выбору, а также четверокурсники выбирают один blended-курс. Студенты групп 17-го года специализаций МОП и ТИ выбирают по 2 осенних и 2 весенних курса по выбору, также студенты групп 18' специализации МИ выбирают 2 осенних курса. <i>Для студентов, которые выбирают 2 курса (например, осенних) первый приоритет — <code>fall_1</code> и <code>fall_2</code>, второй приоритет — <code>fall_3</code>. Такие студенты участвуют только в двух волнах отбора</i>.
#
# - Студенты специализации МОП не могут выбрать весенним курсом по выбору Машинное обучение 2. <i>Если студент специализации МОП выбрал Машинное обучение 2, то его приоритеты сдвигаются. Из-за совпадений первого и второго курса по выбору двигать приоритеты не надо</i>.
#
# - Blended-курсы не трогайте, по ним не надо распределять, на другие курсы они никак не влияют.
#
# - Постарайтесь воздержаться от использования циклов там, где это возможно. <i>Допустимо итерироваться по <b>курсам</b>, на которые проводится отбор, и по <b>волнам</b> отбора. Если вы придумаете, как обойтись и без этих циклов, то на усмотрение проверяющего могут быть добавлены бонусные баллы. <b>Дублирование кода не признается успешным избавлением от циклов</b></i>
#
# - На выходе ожидается файл res_fall.csv с результатами распределения на осенние курсы по выбору. Файл должен быть следующего формата:
#
#     * три столбца: ID, course1, course2
#
#     * Если студент не попал на курс, но должен был, то вместо названия курса в ячейке должна быть строка "???"
#
#     * Если студент должен выбрать только один курс, то в колонке course2 для него должна стоять строка "-"
#
#     * Если студент должен выбрать два курса по выбору, то порядок в колонках course1 и course2 не важен.
#
#     * Формат csv: для сохранения воспользуйтесь df.to_csv('solution.csv', index=None)
#
#
# Для работы вам могут понадобиться следующие данные:
#
# - Результаты опроса (вы уже использовали этот файл в первой части задания, но на всякий случай ссылка: https://www.dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=0)
#
# - Соответствие номеров групп специализациям:
#
#     * 171, 172 - МОП; 173 - ТИ; 174 — АДИС; 175, 176 — РС; 177 — АПР
#
#     * У студентов 18-го года номера групп соответствуют номерам до распределения по специализациям.
#
# - Ограничения по количеству мест на курсах по выбору:
#
#     * Осенние: везде 30 мест, кроме Statistical Learning Theory (60 мест), Высокопроизводительных вычислений (60 мест), Анализа неструктурированных данных ($\infty$ мест)
#
#     * Весенние: везде 30 мест, кроме Обучения с подкреплением (60 мест), Анализа данных в бизнесе (60 мест).
#
#
# Кстати, убедитесь, что в данных больше нет пропусков и повторных записей.

# %% [markdown]
# #### 0. Проверка
#
# Для начала давайте убедимся, что вы успешно выполнили задания первой части и проверим ваши данные на наличие пропусков и повторов:

# %%
assert data.shape[0] == 347, 'В таблице остались повторы или потеряны данные'

assert data.isna().sum().sum() == 0, 'В таблице остались пропуски'

# %% [markdown]
# Если вы не получили AssertionError, то можете продолжать.

# %% [markdown]
# #### 1. [1 балл] Создайте новый признак, обозначающий, сколько осенних курсов должен выбрать студент
#
# В этом вам может помочь информация о специализации и группе стундента.

# %%
data['fall_course_amount'] = np.ones(data.shape[0])
data.loc[data['17_group'].isin([171, 172, 173]), 'fall_course_amount'] = 2
data.loc[data['is_mi'] == 1, 'fall_course_amount'] = 2
data.head(3)
# Out:
#                   timestamp                                id  rating  \
# 161 2020-05-18 22:08:11.668  00b40fe7dbfd23e5daba765244509415     542
# 76  2020-05-18 16:47:43.131  014b72217e20370dab7acc48b20c47be     543
# 335 2020-05-18 23:01:39.666  01b072a0cdb45814fc4ab8ca3e621f0e    1058
#
#      18_group  is_mi                                           fall_1  \
# 161     187.0    0.0                 Безопасность компьютерных систем
# 76      186.0    0.0  Сбор и обработка данных с помощью краудсорсинга
# 335       0.0    0.0                Анализ неструктурированных данных
#
#                                               fall_2  \
# 161                                         Язык SQL
# 76                       Statistical Learning Theory
# 335  Сбор и обработка данных с помощью краудсорсинга
#
#                             fall_3  \
# 161           Матричные вычисления
# 76            Матричные вычисления
# 335  Моделирование временных рядов
#
#                                         spring_1             spring_2  \
# 161  Промышленное программирование на языке Java    Компьютерные сети
# 76                            Системы баз данных  Машинное обучение 2
# 335                     Обучение с подкреплением  Компьютерное зрение
#
#                     spring_3 is_first_time  percentile  17_group  \
# 161  Анализ данных в бизнесе            Да    0.896861       0.0
# 76    Дискретная оптимизация            Да    0.892377       0.0
# 335    Символьные вычисления            Да    0.847826     173.0
#
#                             blended  is_ml_student  fall_course_amount
# 161                                            0.0                 1.0
# 76                                             0.0                 1.0
# 335  Соревновательный анализ данных            0.0                 2.0

# %% [markdown]
# Проверка:

# %%
col_name = 'fall_course_amount'    # insert your new column name as str
df = data

assert(df[df['id'] == '2662600c2c37e11e62f6ee0b88452f22'][col_name] == 2).all()
assert(df[df['id'] == 'd555d2805e1d93d4f023e57dc4c8f403'][col_name] == 2).all()
assert(df[df['id'] == '8fe79f84f36e3a5d2d6745621321302c'][col_name] == 1).all()
assert(df[df['id'] == 'e4caca755ee0bdd711e18fb8084958b5'][col_name] == 1).all()

# %% [markdown]
# #### 2. [2 балла] Распределите студентов в соответствии с первым приоритетом

# %%
set_subj = set()
for col in ['fall_1', 'fall_2', 'fall_3']:
    set_subj.update(set(data[col].unique()))
len(set_subj)
# Out:
# 12

# %% [markdown]
# Всего 12 предметов по выбору на осень

# %%
dict_subj = dict.fromkeys(set_subj, 30)
dict_subj['Statistical Learning Theory'] = 60
dict_subj['Высокопроизводительные вычисления'] = 60
dict_subj['Анализ неструктурированных данных'] = 400  # так как мест не ограниченно

# %%
for col in ['elective_course_1', 'elective_course_2']:
    data[col] = np.full(data.shape[0], fill_value='-')

for subj, course_size in dict_subj.items():
    # выбираем топ студентов с данным приоритетом
    tmp_pool = data[(data['fall_1'] == subj) |
                    ((data['fall_course_amount'] == 2) & (data['fall_2'] == subj))].copy()
    if tmp_pool.shape[0] > course_size:
        tmp_pool = tmp_pool.sort_values(by='percentile')
        tmp_pool = tmp_pool[0:course_size]
    
    # добавим распределение по курсам
    tmp_pool_1 = tmp_pool[tmp_pool['elective_course_1'] == '-'].copy()
    tmp_pool_2 = tmp_pool[tmp_pool['elective_course_1'] != '-'].copy()
    
    data.loc[data['id'].isin(tmp_pool_1['id']), 'elective_course_1'] = subj
    data.loc[data['id'].isin(tmp_pool_2['id']), 'elective_course_2'] = subj

# %% [markdown]
# Здесь для проверки приведена таблица, в которой есть 2 дополнительные колонки:
#
#     1) is_first_place - является ли студент лучшим по перцентили хотя бы на одном из курсов, куда он был зачислен
#     (True / NaN)
#
#     2) is_last_place  - является ли студент худшим по перцентили хотя бы на одном из курсов, куда он был зачислен (True / NaN)

# %%
#!wget  -O '2_task_check.csv' -q 'https://www.dropbox.com/s/v8o2zzq3iz5gc9w/_2_task_check.csv?dl=0'
#import wget 
#wget.download('https://www.dropbox.com/s/v8o2zzq3iz5gc9w/_2_task_check.csv?dl=0',
#              '2_task_check.csv')

# %%
check_df = pd.read_csv('2_task_check.csv')

# %% [markdown]
# После распределения студентов в соответствии с первым приоритетом добавьте в свой датафрейм аналогичные признаки и запустите проверку:

# %%
for col in ['is_first_place', 'is_last_place']:
    data[col] = np.full(shape=data.shape[0], fill_value=np.nan)

for subj, v in dict_subj.items():
    tmp = data[(data['elective_course_1'] == subj) | 
               ((data['fall_course_amount'] == 2) & (data['elective_course_2'] == subj))].copy()
    tmp = tmp.sort_values('percentile')
    
    data.loc[data['id'] == tmp.iloc[0]['id'], 'is_first_place'] = True
    data.loc[data['id'] == tmp.iloc[-1]['id'], 'is_last_place'] = True

# %%
fir_col_name = 'is_first_place'      # insert name of your new column with is_first_place as str
last_col_name = 'is_last_place'     # insert name of your new column with is_last_place as str
df = data.copy()

assert((df[df[fir_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
        ==
        check_df[check_df['is_first_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
       ).id.values).all()


assert((df[df[last_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
       == 
       check_df[check_df['is_last_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
      ).id.values).all()

# %% [markdown]
# # После первого этапа отбора "guessed 242 out of 347"
# ### получилось после второго прохода добиться "guessed 302 out of 347"
# ### получилось после третьего прохода добиться "guessed 304 out of 347"

# %% [markdown]
# #### 3. [3 балла] Проведите все три волны отбора студентов на курсы по выбору

# %% [markdown]
# Вторая волна:

# %%
"""
dict_subj_low_perc = {'Безопасность компьютерных систем': 30,
 'Сбор и обработка данных с помощью краудсорсинга': 30,
 'Байесовские методы машинного обучения': 30,
 'Высокопроизводительные вычисления': 60,
'Язык SQL': 30,
 'Теория баз данных': 30,
 'Матричные вычисления': 30,
 'Глубинное обучение в обработке звука': 30,
 'Моделирование временных рядов': 30,
 'Statistical Learning Theory': 60,
 'Анализ неструктурированных данных': 400,
 'Принятие решений в условиях риска и неопределённости': 30}
"""
# Out:
# "\ndict_subj_low_perc = {'Безопасность компьютерных систем': 30,\n 'Сбор и обработка данных с помощью краудсорсинга': 30,\n 'Байесовские методы машинного обучения': 30,\n 'Высокопроизводительные вычисления': 60,\n'Язык SQL': 30,\n 'Теория баз данных': 30,\n 'Матричные вычисления': 30,\n 'Глубинное обучение в обработке звука': 30,\n 'Моделирование временных рядов': 30,\n 'Statistical Learning Theory': 60,\n 'Анализ неструктурированных данных': 400,\n 'Принятие решений в условиях риска и неопределённости': 30}\n"

# %%
#dict_subj_low_perc

# %%
dict_subj_low_perc = {}
for subj, course_size in dict_subj.items():
    dict_subj_low_perc[subj] = data.loc[((data['elective_course_1'] == subj) |
                                         (data['elective_course_2'] == subj)), 'percentile'].max()

sorted_tuples = sorted(dict_subj_low_perc.items(), key=lambda item: item[1])
sorted_dict_subj_low_perc = {k: v for k, v in sorted_tuples}
sorted_dict_subj_low_perc
# Out:
# {'Безопасность компьютерных систем': 0.2107623318385651,
#  'Сбор и обработка данных с помощью краудсорсинга': 0.6376811594202898,
#  'Байесовские методы машинного обучения': 0.9057971014492754,
#  'Высокопроизводительные вычисления': 0.9192825112107623,
#  'Теория баз данных': 0.9237668161434978,
#  'Матричные вычисления': 0.9327354260089686,
#  'Глубинное обучение в обработке звука': 0.9637681159420289,
#  'Язык SQL': 0.968609865470852,
#  'Моделирование временных рядов': 0.9710144927536232,
#  'Statistical Learning Theory': 0.9730941704035875,
#  'Анализ неструктурированных данных': 0.9927536231884058,
#  'Принятие решений в условиях риска и неопределённости': 0.9955156950672646}

# %%
dsfaavdsvasd
subj = 'Принятие решений в условиях риска и неопределённости'
tmp_pool = data[(((data['fall_2'] == subj) &
                     (data['fall_course_amount'] == 1) &
                     (data['elective_course_1'] == '-'))
                    |
                    ((data['fall_3'] == subj) &
                     (data['fall_course_amount'] == 2) &
                     (data['elective_course_2'] == '-'))
                    |
                    (data['elective_course_1'] == subj)
                    |
                    (data['elective_course_2'] == subj))].copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-be94ba11ce5a> in <module>
# ----> 1 dsfaavdsvasd
#       2 subj = 'Принятие решений в условиях риска и неопределённости'
#       3 tmp_pool = data[(((data['fall_2'] == subj) &
#       4                      (data['fall_course_amount'] == 1) &
#       5                      (data['elective_course_1'] == '-'))
#
# NameError: name 'dsfaavdsvasd' is not defined

# %%
tmp_pool.sort_values('percentile')

# %%
tmp_pool.shape

# %%
if tmp_pool.shape[0] > dict_subj[subj]:
    print('yes')
    tmp_pool = tmp_pool.sort_values(by='percentile')
    doubt = tmp_pool[dict_subj[subj]:].copy()
    tmp_pool = tmp_pool[0:dict_subj[subj]]

# %%
doubt

# %%
data[data['elective_course_1'] == 'Матричные вычисления'].sort_values('percentile')

# %%
# исключаю тех, кого вытеснили
data.loc[data['id'].isin(
            doubt.loc[(doubt['elective_course_1'] == subj), 'id']), 'elective_course_1'] = '-'

# %%
data.loc[data['id'].isin(
            doubt.loc[(doubt['elective_course_2'] == subj), 'id']), 'elective_course_2'] = '-'

# %%
doubt

# %%
data[data['id'] == 'bba51e2f648cb3323b96858a404dacea']

# %%
data.loc[(data['elective_course_1'] == '-') &
                 (data['elective_course_2'] != '-'),
                 'elective_course_1'] = data['elective_course_2']

# %%
data[data['id'] == 'c1e88502b6673d22c38ee1352e3a1dd9']

# %%
data.loc[(data['elective_course_1'] == data['elective_course_2']),
                 'elective_course_2'] = '-'

# %%
data[data['id'] == 'c1e88502b6673d22c38ee1352e3a1dd9']

# %%
tmp_pool_1 = tmp_pool[tmp_pool['elective_course_1'] == '-'].copy()
tmp_pool_2 = tmp_pool[(tmp_pool['fall_course_amount'] == 2) & 
                      (tmp_pool['elective_course_2'] == '-') &
                      (tmp_pool['elective_course_1'] != '-') &
                      (tmp_pool['elective_course_1'] != subj)].copy()

# %%
tmp_pool_1

# %%
tmp_pool_2

# %%
data.loc[data['id'].isin(tmp_pool_1['id']), 'elective_course_1'] = subj
data.loc[data['id'].isin(tmp_pool_2['id']), 'elective_course_2'] = subj

# %%
data[data['id'] == '31e38f7596f83b72ebba1c6fc6b7a590']

# %%
for subj, v in dict_subj_low_perc.items():
    # выбираем топ студентов с данным приоритетом
    tmp_pool = data[(((data['fall_2'] == subj) &
                     (data['fall_course_amount'] == 1) &
                     (data['elective_course_1'] == '-'))
                    |
                    ((data['fall_3'] == subj) &
                     (data['fall_course_amount'] == 2) &
                     (data['elective_course_2'] == '-'))
                    |
                    (data['elective_course_1'] == subj)
                    |
                    (data['elective_course_2'] == subj))].copy()

    if tmp_pool.shape[0] > dict_subj[subj]:
        tmp_pool = tmp_pool.sort_values(by='percentile')
        doubt = tmp_pool[dict_subj[subj]:].copy()
        tmp_pool = tmp_pool[0:dict_subj[subj]]
        # исключаю тех, кого вытеснили
        data.loc[data['id'].isin(
            doubt.loc[(doubt['elective_course_1'] == subj), 'id']), 'elective_course_1'] = '-'
        data.loc[data['id'].isin(
            doubt.loc[(doubt['elective_course_2'] == subj), 'id']), 'elective_course_2'] = '-'
        # привожу колонки в порядок
        data.loc[(data['elective_course_1'] == '-') &
                 (data['elective_course_2'] != '-'),
                 'elective_course_1'] = data['elective_course_2']
        data.loc[(data['elective_course_1'] == data['elective_course_2']),
                 'elective_course_2'] = '-'

    # добавим распределение по курсам
    tmp_pool_1 = tmp_pool[tmp_pool['elective_course_1'] == '-'].copy()
    tmp_pool_2 = tmp_pool[(tmp_pool['fall_course_amount'] == 2) & 
                          (tmp_pool['elective_course_2'] == '-') &
                          (tmp_pool['elective_course_1'] != '-') &
                          (tmp_pool['elective_course_1'] != subj)].copy()
    
    data.loc[data['id'].isin(tmp_pool_1['id']), 'elective_course_1'] = subj
    data.loc[data['id'].isin(tmp_pool_2['id']), 'elective_course_2'] = subj

# %%
tmp_pool

# %%
data[data['elective_course_1'] == '-'].sort_values('percentile')

# %% [markdown]
# Третья волна:

# %%
dict_subj_low_perc = {}
for subj, course_size in dict_subj.items():
    dict_subj_low_perc[subj] = data.loc[((data['elective_course_1'] == subj) |
                                        (data['elective_course_2'] == subj)), 'percentile'].max()

sorted_tuples = sorted(dict_subj_low_perc.items(), key=lambda item: item[1])
sorted_dict_subj_low_perc = {k: v for k, v in sorted_tuples}
sorted_dict_subj_low_perc
# Out:
# {'Безопасность компьютерных систем': 0.2107623318385651,
#  'Сбор и обработка данных с помощью краудсорсинга': 0.5201793721973094,
#  'Высокопроизводительные вычисления': 0.7802690582959642,
#  'Язык SQL': 0.8026905829596412,
#  'Моделирование временных рядов': 0.8295964125560538,
#  'Матричные вычисления': 0.9327354260089686,
#  'Байесовские методы машинного обучения': 0.9637681159420289,
#  'Statistical Learning Theory': 0.9730941704035875,
#  'Теория баз данных': 0.9775784753363229,
#  'Глубинное обучение в обработке звука': 0.9782608695652174,
#  'Анализ неструктурированных данных': 0.9927536231884058,
#  'Принятие решений в условиях риска и неопределённости': 0.9955156950672646}

# %%
for subj, v in dict_subj_low_perc.items():
    # выбираем топ студентов с данным приоритетом
    tmp_pool = data[((data['fall_3'] == subj) &
                     (data['fall_course_amount'] == 1) &
                     (data['elective_course_1'] == '-'))
                    |
                    (data['elective_course_1'] == subj)
                    |
                    (data['elective_course_2'] == subj)].copy()
    
    if tmp_pool.shape[0] > dict_subj[subj]:
        tmp_pool = tmp_pool.sort_values(by='percentile')
        doubt = tmp_pool[dict_subj[subj]:].copy()
        tmp_pool = tmp_pool[0:dict_subj[subj]]
        # исключаю тех, кого вытеснили
        data.loc[data['id'].isin(
            doubt.loc[(doubt['elective_course_1'] == subj), 'id']), 'elective_course_1'] = '-'
        data.loc[data['id'].isin(
            doubt.loc[(doubt['elective_course_2'] == subj), 'id']), 'elective_course_2'] = '-'
        # привожу колонки в порядок
        data.loc[(data['elective_course_1'] == '-') &
                 (data['elective_course_2'] != '-'),
                 'elective_course_1'] = data['elective_course_2']
        data.loc[(data['elective_course_1'] == data['elective_course_2']),
                 'elective_course_2'] = '-'

    # добавим распределение по курсам
    tmp_pool_1 = tmp_pool[tmp_pool['elective_course_1'] == '-'].copy()
    tmp_pool_2 = tmp_pool[(tmp_pool['fall_course_amount'] == 2) & 
                          (tmp_pool['elective_course_2'] == '-') &
                          (tmp_pool['elective_course_1'] != '-') &
                          (tmp_pool['elective_course_1'] != subj)].copy()
    # по идее tmp_pool_2 всегда должно быть пустым во время третьей волны,
    # так как тут люди, которые выбирают два курса вообще не рассматриваются
    # (надо бы это проверить, если что)
    
    data.loc[data['id'].isin(tmp_pool_1['id']), 'elective_course_1'] = subj
    data.loc[data['id'].isin(tmp_pool_2['id']), 'elective_course_2'] = subj

# %% [markdown]
# Дозаполнение таблицы:

# %%
data.loc[data['elective_course_1'] == '-', 'elective_course_1'] = '???'
data.loc[(data['fall_course_amount'] == 2) & (data['elective_course_2'] == '-'),
         'elective_course_2'] = '???'

df = pd.DataFrame(data=data[['id', 'elective_course_1', 'elective_course_2']])
df = df.rename(columns={'id' : 'ID',
                        'elective_course_1' : 'course1',
                        'elective_course_2' : 'course2'})
df.to_csv('res_fall.csv', index=None)

# %%
tmp_dict_subj_low_perc = {}
for subj, course_size in dict_subj.items():
    tmp_dict_subj_low_perc[subj] = data.loc[((data['elective_course_1'] == subj) |
                                            (data['elective_course_2'] == subj)),
                                            'percentile'].max()

sorted_tuples = sorted(tmp_dict_subj_low_perc.items(), key=lambda item: item[1])
sorted_tmp_dict_subj_low_perc = {k: v for k, v in sorted_tuples}
sorted_tmp_dict_subj_low_perc
# Out:
# {'Безопасность компьютерных систем': 0.2107623318385651,
#  'Сбор и обработка данных с помощью краудсорсинга': 0.5201793721973094,
#  'Высокопроизводительные вычисления': 0.7802690582959642,
#  'Язык SQL': 0.789237668161435,
#  'Моделирование временных рядов': 0.8295964125560538,
#  'Матричные вычисления': 0.9103139013452914,
#  'Байесовские методы машинного обучения': 0.9637681159420289,
#  'Statistical Learning Theory': 0.9730941704035875,
#  'Глубинное обучение в обработке звука': 0.9782608695652174,
#  'Теория баз данных': 0.9820627802690582,
#  'Анализ неструктурированных данных': 0.9927536231884058,
#  'Принятие решений в условиях риска и неопределённости': 0.9955156950672646}

# %%
"""
data.loc[data['id'] == '3a7326c9e355a67d3805824ca34c4bc5',
         'elective_course_1'] = 'Statistical Learning Theory'
data.loc[data['id'] == '3a7326c9e355a67d3805824ca34c4bc5',
         'elective_course_2'] = 'Высокопроизводительные вычисления'
data.loc[data['id'] == '3e106aaef8b24dbb01319c73e14c2936',
         'elective_course_1'] = 'Безопасность компьютерных систем'
data.loc[data['id'] == '3e106aaef8b24dbb01319c73e14c2936',
         'elective_course_2'] = '-'
"""

# %%
data.loc[(data['elective_course_1'] == '???') |
         (data['elective_course_2'] == '???')].sort_values('percentile')
# Out:
#                   timestamp                                id  rating  \
# 239 2020-05-14 23:33:21.310  e0fceae1e285f737630bb6123a1bd85d    1203
# 295 2020-05-18 18:27:32.822  7fcf56aae6836855a689000a50e80360    1145
# 294 2020-05-18 18:24:13.190  6338b6eeb16faedc58d30d2f45c89a4c    1132
# 44  2020-05-17 12:11:23.296  39cd1820459fdbcc193f9bb0ddb74a58     606
# 309 2020-05-18 21:09:04.370  fa61e55c68763160d0fffe57dab37af9    1121
# 233 2020-05-14 22:14:39.567  3e88c8d53bcd73595d2bbcdd8c51c1bf    1118
# 199 2020-05-18 23:47:37.254  b75b5f8abebf7faf4adbb6247d6d03bb     590
# 316 2020-05-18 21:46:53.813  d40cbae8cfc9e6c5d05831ef7e122f3e    1092
# 310 2020-05-18 21:14:10.549  e0a59b2b04663ea386d2cac7b876952e    1091
# 7   2020-05-15 12:11:43.252  8047c18b3c531c6f47931e0744f3e028     566
# 236 2020-05-14 22:57:27.437  5d1deb0ae3a69348a018881ac785fd90    1066
# 299 2020-05-18 19:36:56.962  0c0cbdd1a309c1d1fd8993c4dc907bb5    1065
# 117 2020-05-18 20:21:46.887  6cd7de3774f07c65e44668cdf7e987b6     557
# 74  2020-05-18 16:11:14.717  635e9ca4fcf26a2bd38b8488a8edfca5     555
# 335 2020-05-18 23:01:39.666  01b072a0cdb45814fc4ab8ca3e621f0e    1058
# 162 2020-05-18 22:08:14.176  cfe9fd28e4cbe0b46594b21f3067e30a     553
# 265 2020-05-17 18:29:44.851  bba51e2f648cb3323b96858a404dacea    1052
# 245 2020-05-16 01:07:58.660  180cf0e0dc7a6f88e76e3076cb761d26    1051
# 341 2020-05-18 23:13:30.565  085da16dd3062b4790c3dabdc08a51cf    1048
# 40  2020-05-17 00:54:43.939  d38ebd0ba564ea88de8015e116f811c8     546
# 156 2020-05-18 21:57:39.924  7f8feb54319e52cb63ad437f4128a9d8     540
# 253 2020-05-17 14:35:15.171  a31027b4218c8cca257f9b9cd07791d2    1032
# 43  2020-05-17 12:04:22.843  b6bf56b8b8ffd1666036b0a8ca01c452     537
# 166 2020-05-18 22:15:41.331  b4f1f195bd1bc63490a7bc42275a71cd     536
# 311 2020-05-18 21:20:14.429  ba4091ee80dd63a042464dbd2a7e3363    1022
# 154 2020-05-18 21:54:53.944  ac2fd77f2ec0186c95f16e6721fd5998     533
# 70  2020-05-18 14:18:18.644  d9f0e5ebc6718202b86eaee2de1c697b     531
# 280 2020-05-18 13:51:01.165  c749f69f66d40cdfb3821745951be896    1017
# 351 2020-05-18 23:58:33.903  8fe79f84f36e3a5d2d6745621321302c    1016
# 39  2020-05-16 23:49:50.765  ab5248060fbaac411a79a62dfb0d263d     528
# 86  2020-05-18 17:51:56.025  9f23846141606a1e26e8e4c28e9a7262     527
# 164 2020-05-18 22:09:59.005  dbcac463fe0b6294743107a9e74356c5     525
# 38  2020-05-16 23:32:44.820  e3d4f9a7b947ebc03d345dd9e14b5d2c     524
# 52  2020-05-17 18:45:15.768  ef8c6afd958da5f51429948f090432da     522
# 135 2020-05-18 21:19:50.620  feb53dcdd28fff9dc4a981c3419fea6f     521
# 264 2020-05-17 18:04:39.903  c1e88502b6673d22c38ee1352e3a1dd9     985
# 170 2020-05-18 22:29:14.162  40b18d40197e3db66312a026e06b8ff1     515
# 128 2020-05-18 21:12:00.134  be4fa2120de3397ae21eac38ff0060e3     502
#
#      18_group  is_mi                                           fall_1  \
# 239       0.0    0.0                Высокопроизводительные вычисления
# 295       0.0    0.0                 Безопасность компьютерных систем
# 294       0.0    0.0  Сбор и обработка данных с помощью краудсорсинга
# 44      184.0    1.0                 Безопасность компьютерных систем
# 309       0.0    0.0                Анализ неструктурированных данных
# 233       0.0    0.0            Байесовские методы машинного обучения
# 199     184.0    1.0                 Безопасность компьютерных систем
# 316       0.0    0.0                 Безопасность компьютерных систем
# 310       0.0    0.0                Анализ неструктурированных данных
# 7       187.0    0.0                                         Язык SQL
# 236       0.0    0.0                Высокопроизводительные вычисления
# 299       0.0    0.0                 Безопасность компьютерных систем
# 117     183.0    0.0                    Моделирование временных рядов
# 74      186.0    0.0  Сбор и обработка данных с помощью краудсорсинга
# 335       0.0    0.0                Анализ неструктурированных данных
# 162     188.0    0.0                                         Язык SQL
# 265       0.0    0.0  Сбор и обработка данных с помощью краудсорсинга
# 245       0.0    0.0                 Безопасность компьютерных систем
# 341       0.0    0.0                 Безопасность компьютерных систем
# 40      187.0    0.0                 Безопасность компьютерных систем
# 156     186.0    0.0  Сбор и обработка данных с помощью краудсорсинга
# 253       0.0    0.0                Анализ неструктурированных данных
# 43      181.0    0.0                             Матричные вычисления
# 166     187.0    0.0                Высокопроизводительные вычисления
# 311       0.0    0.0                 Безопасность компьютерных систем
# 154     184.0    0.0                 Безопасность компьютерных систем
# 70      186.0    0.0                             Матричные вычисления
# 280       0.0    0.0                Анализ неструктурированных данных
# 351       0.0    0.0                 Безопасность компьютерных систем
# 39      187.0    0.0                                         Язык SQL
# 86      187.0    0.0                 Безопасность компьютерных систем
# 164     186.0    0.0  Сбор и обработка данных с помощью краудсорсинга
# 38      181.0    0.0                 Безопасность компьютерных систем
# 52      183.0    0.0  Сбор и обработка данных с помощью краудсорсинга
# 135     186.0    1.0                 Безопасность компьютерных систем
# 264       0.0    0.0                Анализ неструктурированных данных
# 170     188.0    0.0                 Безопасность компьютерных систем
# 128     187.0    0.0                 Безопасность компьютерных систем
#
#                                               fall_2  \
# 239                Высокопроизводительные вычисления
# 295                 Безопасность компьютерных систем
# 294                    Моделирование временных рядов
# 44   Сбор и обработка данных с помощью краудсорсинга
# 309                 Безопасность компьютерных систем
# 233  Сбор и обработка данных с помощью краудсорсинга
# 199                      Statistical Learning Theory
# 316  Сбор и обработка данных с помощью краудсорсинга
# 310                 Безопасность компьютерных систем
# 7                                  Теория баз данных
# 236                 Безопасность компьютерных систем
# 299  Сбор и обработка данных с помощью краудсорсинга
# 117                                         Язык SQL
# 74                  Безопасность компьютерных систем
# 335  Сбор и обработка данных с помощью краудсорсинга
# 162  Сбор и обработка данных с помощью краудсорсинга
# 265                    Моделирование временных рядов
# 245                Высокопроизводительные вычисления
# 341  Сбор и обработка данных с помощью краудсорсинга
# 40                 Высокопроизводительные вычисления
# 156                 Безопасность компьютерных систем
# 253  Сбор и обработка данных с помощью краудсорсинга
# 43                                          Язык SQL
# 166                 Безопасность компьютерных систем
# 311  Сбор и обработка данных с помощью краудсорсинга
# 154                             Матричные вычисления
# 70                 Высокопроизводительные вычисления
# 280  Сбор и обработка данных с помощью краудсорсинга
# 351                Высокопроизводительные вычисления
# 39                  Безопасность компьютерных систем
# 86   Сбор и обработка данных с помощью краудсорсинга
# 164                 Безопасность компьютерных систем
# 38                 Высокопроизводительные вычисления
# 52                 Высокопроизводительные вычисления
# 135                                         Язык SQL
# 264                    Моделирование временных рядов
# 170                                         Язык SQL
# 128                                         Язык SQL
#
#                                               fall_3  \
# 239                Высокопроизводительные вычисления
# 295                 Безопасность компьютерных систем
# 294                Анализ неструктурированных данных
# 44                       Statistical Learning Theory
# 309  Сбор и обработка данных с помощью краудсорсинга
# 233                Анализ неструктурированных данных
# 199  Сбор и обработка данных с помощью краудсорсинга
# 316                Анализ неструктурированных данных
# 310  Сбор и обработка данных с помощью краудсорсинга
# 7                   Безопасность компьютерных систем
# 236                      Statistical Learning Theory
# 299                    Моделирование временных рядов
# 117                Высокопроизводительные вычисления
# 74                                          Язык SQL
# 335                    Моделирование временных рядов
# 162                Высокопроизводительные вычисления
# 265                Анализ неструктурированных данных
# 245  Сбор и обработка данных с помощью краудсорсинга
# 341                Высокопроизводительные вычисления
# 40                                          Язык SQL
# 156                                         Язык SQL
# 253                 Безопасность компьютерных систем
# 43                  Безопасность компьютерных систем
# 166                                         Язык SQL
# 311                    Моделирование временных рядов
# 154  Сбор и обработка данных с помощью краудсорсинга
# 70                                          Язык SQL
# 280                    Моделирование временных рядов
# 351  Сбор и обработка данных с помощью краудсорсинга
# 39   Сбор и обработка данных с помощью краудсорсинга
# 86                                          Язык SQL
# 164                    Моделирование временных рядов
# 38                              Матричные вычисления
# 52                              Матричные вычисления
# 135  Сбор и обработка данных с помощью краудсорсинга
# 264  Сбор и обработка данных с помощью краудсорсинга
# 170  Сбор и обработка данных с помощью краудсорсинга
# 128                             Матричные вычисления
#
#                                               spring_1  \
# 239  Проектирование и разработка высоконагруженных ...
# 295                              Символьные вычисления
# 294                           Обучение с подкреплением
# 44                                 Машинное обучение 2
# 309                           Обучение с подкреплением
# 233                                Компьютерное зрение
# 199                            Анализ данных в бизнесе
# 316  Проектирование и разработка высоконагруженных ...
# 310                           Обучение с подкреплением
# 7          Промышленное программирование на языке Java
# 236               Методы сжатия и передачи медиаданных
# 299                                Компьютерное зрение
# 117        Промышленное программирование на языке Java
# 74          Дополнительные главы прикладной статистики
# 335                           Обучение с подкреплением
# 162        Промышленное программирование на языке Java
# 265               Методы сжатия и передачи медиаданных
# 245  Проектирование и разработка высоконагруженных ...
# 341  Проектирование и разработка высоконагруженных ...
# 40                                   Компьютерные сети
# 156                                Машинное обучение 2
# 253                           Обучение с подкреплением
# 43                                   Компьютерные сети
# 166                                  Компьютерные сети
# 311  Проектирование и разработка высоконагруженных ...
# 154                                 Системы баз данных
# 70                                   Компьютерные сети
# 280                           Обучение с подкреплением
# 351                             Конфликты и кооперация
# 39         Промышленное программирование на языке Java
# 86                                   Компьютерные сети
# 164                                Машинное обучение 2
# 38                              Дискретная оптимизация
# 52                                 Машинное обучение 2
# 135        Промышленное программирование на языке Java
# 264                           Обучение с подкреплением
# 170        Промышленное программирование на языке Java
# 128        Промышленное программирование на языке Java
#
#                                               spring_2  ... is_first_time  \
# 239  Проектирование и разработка высоконагруженных ...  ...            Да
# 295                              Символьные вычисления  ...            Да
# 294                             Конфликты и кооперация  ...            Да
# 44         Промышленное программирование на языке Java  ...            Да
# 309                                Компьютерное зрение  ...            Да
# 233  Проектирование и разработка высоконагруженных ...  ...            Да
# 199                                  Компьютерные сети  ...           Нет
# 316                           Обучение с подкреплением  ...            Да
# 310                                Компьютерное зрение  ...            Да
# 7                                    Компьютерные сети  ...            Да
# 236                              Символьные вычисления  ...            Да
# 299               Методы сжатия и передачи медиаданных  ...            Да
# 117                            Анализ данных в бизнесе  ...            Да
# 74                                  Системы баз данных  ...            Да
# 335                                Компьютерное зрение  ...            Да
# 162                            Анализ данных в бизнесе  ...            Да
# 265                           Обучение с подкреплением  ...            Да
# 245                             Конфликты и кооперация  ...            Да
# 341               Методы сжатия и передачи медиаданных  ...            Да
# 40         Промышленное программирование на языке Java  ...            Да
# 156                                  Компьютерные сети  ...            Да
# 253                             Конфликты и кооперация  ...            Да
# 43         Промышленное программирование на языке Java  ...            Да
# 166        Промышленное программирование на языке Java  ...            Да
# 311               Методы сжатия и передачи медиаданных  ...            Да
# 154                                  Компьютерные сети  ...            Да
# 70                                  Системы баз данных  ...            Да
# 280  Проектирование и разработка высоконагруженных ...  ...            Да
# 351  Проектирование и разработка высоконагруженных ...  ...            Да
# 39          Дополнительные главы прикладной статистики  ...            Да
# 86         Промышленное программирование на языке Java  ...            Да
# 164                                  Компьютерные сети  ...           Нет
# 38                                 Машинное обучение 2  ...            Да
# 52                              Дискретная оптимизация  ...            Да
# 135                            Анализ данных в бизнесе  ...           Нет
# 264                                Компьютерное зрение  ...            Да
# 170                                  Компьютерные сети  ...           Нет
# 128                                   Численные методы  ...            Да
#
#     percentile  17_group                                blended is_ml_student  \
# 239   0.311594     173.0                                 DevOps           0.0
# 295   0.536232     173.0  Введение в дифференциальную геометрию           0.0
# 294   0.579710     172.0         Соревновательный анализ данных           0.0
# 44    0.623318       0.0                                                  0.0
# 309   0.630435     172.0                                 DevOps           0.0
# 233   0.637681     172.0                                 DevOps           0.0
# 199   0.695067       0.0                                                  0.0
# 316   0.724638     172.0                                 DevOps           0.0
# 310   0.731884     172.0                                 DevOps           0.0
# 7     0.802691       0.0                                                  0.0
# 236   0.826087     173.0                                 DevOps           0.0
# 299   0.833333     172.0         Соревновательный анализ данных           0.0
# 117   0.843049       0.0                                                  1.0
# 74    0.847534       0.0                                                  1.0
# 335   0.847826     173.0         Соревновательный анализ данных           0.0
# 162   0.856502       0.0                                                  0.0
# 265   0.862319     172.0         Соревновательный анализ данных           0.0
# 245   0.869565     177.0                                 DevOps           0.0
# 341   0.876812     176.0                                 DevOps           0.0
# 40    0.883408       0.0                                                  0.0
# 156   0.905830       0.0                                                  0.0
# 253   0.913043     172.0                                 DevOps           0.0
# 43    0.914798       0.0                                                  0.0
# 166   0.919283       0.0                                                  0.0
# 311   0.927536     176.0                                 DevOps           0.0
# 154   0.928251       0.0                                                  1.0
# 70    0.932735       0.0                                                  0.0
# 280   0.934783     172.0                                 DevOps           0.0
# 351   0.942029     174.0                                 DevOps           0.0
# 39    0.946188       0.0                                                  1.0
# 86    0.950673       0.0                                                  0.0
# 164   0.955157       0.0                                                  0.0
# 38    0.959641       0.0                                                  0.0
# 52    0.964126       0.0                                                  0.0
# 135   0.968610       0.0                                                  0.0
# 264   0.971014     172.0         Соревновательный анализ данных           0.0
# 170   0.986547       0.0                                                  0.0
# 128   0.991031       0.0                                                  0.0
#
#      fall_course_amount                      elective_course_1  \
# 239                 2.0      Высокопроизводительные вычисления
# 295                 2.0                                    ???
# 294                 2.0          Моделирование временных рядов
# 44                  2.0            Statistical Learning Theory
# 309                 2.0      Анализ неструктурированных данных
# 233                 2.0  Байесовские методы машинного обучения
# 199                 2.0            Statistical Learning Theory
# 316                 2.0      Анализ неструктурированных данных
# 310                 2.0      Анализ неструктурированных данных
# 7                   1.0                                    ???
# 236                 2.0            Statistical Learning Theory
# 299                 2.0                                    ???
# 117                 1.0                                    ???
# 74                  1.0                                    ???
# 335                 2.0      Анализ неструктурированных данных
# 162                 1.0                                    ???
# 265                 2.0      Анализ неструктурированных данных
# 245                 1.0                                    ???
# 341                 1.0                                    ???
# 40                  1.0                                    ???
# 156                 1.0                                    ???
# 253                 2.0      Анализ неструктурированных данных
# 43                  1.0                                    ???
# 166                 1.0                                    ???
# 311                 1.0                                    ???
# 154                 1.0                                    ???
# 70                  1.0                                    ???
# 280                 2.0      Анализ неструктурированных данных
# 351                 1.0                                    ???
# 39                  1.0                                    ???
# 86                  1.0                                    ???
# 164                 1.0                                    ???
# 38                  1.0                                    ???
# 52                  1.0                                    ???
# 135                 2.0                                    ???
# 264                 2.0      Анализ неструктурированных данных
# 170                 1.0                                    ???
# 128                 1.0                                    ???
#
#     elective_course_2 is_first_place is_last_place
# 239               ???            NaN           NaN
# 295               ???            NaN           NaN
# 294               ???            NaN           NaN
# 44                ???            NaN           NaN
# 309               ???            NaN           NaN
# 233               ???            NaN          True
# 199               ???            NaN           NaN
# 316               ???            NaN           NaN
# 310               ???            NaN           NaN
# 7                   -            NaN           NaN
# 236               ???            NaN           NaN
# 299               ???            NaN           NaN
# 117                 -            NaN           NaN
# 74                  -            NaN           NaN
# 335               ???            NaN           NaN
# 162                 -            NaN           NaN
# 265               ???            NaN           NaN
# 245                 -            NaN           NaN
# 341                 -            NaN           NaN
# 40                  -            NaN           NaN
# 156                 -            NaN           NaN
# 253               ???            NaN           NaN
# 43                  -            NaN           NaN
# 166                 -            NaN          True
# 311                 -            NaN           NaN
# 154                 -            NaN           NaN
# 70                  -            NaN          True
# 280               ???            NaN           NaN
# 351                 -            NaN           NaN
# 39                  -            NaN           NaN
# 86                  -            NaN           NaN
# 164                 -            NaN           NaN
# 38                  -            NaN           NaN
# 52                  -            NaN           NaN
# 135               ???            NaN          True
# 264               ???            NaN          True
# 170                 -            NaN           NaN
# 128                 -            NaN           NaN
#
# [38 rows x 21 columns]

# %% [markdown]
# **Отправьте свой файл res_fall.csv в контест (https://contest.yandex.ru/contest/29176/problems/A/) и прикрепите/укажите ниже ваш никнейм и ссылку на успешную посылку.**

# %% [markdown]
# *Дисклеймер:*
#
# Контест выдаётся для самопроверки. Если ваша посылка получила ОК, то код, скорее всего, правильный. Но при этом оценка всё равно может быть снижена в случае обнаружения неэффективностей или ошибок в коде. Если вы сдадите в AnyTask очевидно неработающий код или ноутбук без кода, но при этом в контест будет сдан корректный файл, то это будет расцениваться как плагиат.

# %% [markdown]
# На всякий случай просим вас сдать вместе с ноутбуком файл res_fall.csv в anytask

# %% [markdown]
# **Дополнительное задание. [2 бонусных балла] Распределите таким же образом студентов еще и на весенние курсы по выбору.**
#
# Если ваш код был хорошо структурирован, то это не составит проблем.
#
# Если вы выполнили это задание, сдайте среди прочего файл res_spring.csv в таком же формате, как и res_fall.csv.

# %%
# (￣^'￣)ゞ

# %% [markdown]
# **Отправьте свой файл res_spring.csv в контест (https://contest.yandex.ru/contest/29176/problems/B/) и прикрепите/укажите ниже ваш никнейм и ссылку на успешную посылку.**

# %% [markdown]
# На всякий случай просим вас сдать вместе с ноутбуком файл res_spring.csv в anytask

# %% [markdown]
# Вставьте картинку, описывающую ваш опыт выполнения этого задания:
